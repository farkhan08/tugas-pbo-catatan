# %% [markdown]
# Class vs Object
#
# a. Class
#
#     Class adalah suatu tempat untuk membuat suatu objek. Sedangkan objek sendiri mempunyai variavel anggota yang dan perilaku yang sama dengan Class.
#     Struktur data yang bisa kita gunakan untuk mendefinisikan objek yang menyimpan data bersama-sama nilai-nilai dan perilaku (behavior). Kelas adalah suatu entitas yang merupakan bentuk program dari suatu abstraksi untuk permasalahan dunia nyata, dan instans dari class merupakan realisasi dari beberapa objek.
#
# b. Object
#
#     Objek dibuat menggunakan konstruktor kelas,yang kemudian akan disebut turunan dari kelas.Instance dari kelas. Jika kelas secara umum merepresentasikan (template) sebuah object, maka sebuah instance adalah representasi nyata dari kelas itu sendiri
#
#     Intinya adalah kelas itu lebih umum dan object lebih ke jenis-jenis dari kelas tersebut
#
#    Contoh gambar definisi dari kelas dan object
#
# ![](./img/class-object-featured-image-760x330.png)
#
#     Keyword class di python biasanya lansung keyword class diikuti nama kelas yang diinginkan .
#      - Init : Metode khusus yang digunakan untuk menginisialisasi pembuatan object dari kelas yang dibuat
#      - Method : Setiap method harus memiliki parameter self yang artinya method tersebut dimiliki dan terdaftar                                 ke class tersebut untuk membedakan dari method atau fungsi yang ada di luar class
#      - Mengakses Method biasanya menggunakan titik
#
#
#    contoh kodingan Class vs Object

# %%
class kubus :
    def __init__(self,s):
        self.sisi=s
    def tampilkan (self):
        print ("Kubus dengan sisi : ",self.sisi)
    def luas(self):
        l=(self.sisi*self.sisi)
        print("Luasnya : ",l)
    def keliling (self):
        k=4*(self.sisi)
        print("Kelilingnya  : ",k)
obj=kubus(8)
obj.tampilkan()
obj.luas()
obj.keliling()
# Out:
# ('Kubus dengan sisi : ', 8)
# ('Luasnya : ', 64)
# ('Kelilingnya  : ', 32)

# %% [markdown]
# 1. Inheritance
#
# Pewarisan, kelas juga dapat mewarisi kelas yang lain Jika suatu objek dibuat menggunakan kelas yang mewarisi dari superclass, objek tersebut akan berisi metode kelas dan superclass. Sama seperti pewarisan dalam biologi, anak mewarisi tinggi, warna kulit dan lain sebagainya dari ayahnya.
# ![](./img/single-inheritance.png)
#     Dalam gambar tersebut kelas A adalah kelas induk dan B adalah warisannya.
#
# contoh kita mendefinisikan class induk User dan menampilkan contoh
# ![](./img/user.jpg)
#
# lalu kita membuat kelas turunan bernama Progammer yang menunjukkan fungsi yang sama dengan induknya, yang artinya fungsi dari kelas User dapat diakses di kelas turunannya yaitu Progammer.
#
# ![](./img/1.jpg)
#
#
# Selanjutnya kita panggil objek
#
# ![](./img/03.jpg)
#
#
#
# Lalu outputnya akan seperti ini
#
# ![](./img/:04.jpg)
#
#
# 2. Type of Inheritance
#
#     Jenis-jenis Inheritance :
#         a. Default
#         b. Overriding
#         c. Super
#         d. Multiple
# ![](./img/image.png)
#
# a. Default
#
#     Inheritance jenis default ini sama dengan yang diatas..
# ![](./img/kfdsbv.jpg)
#
# b. Overriding
#
#     Overriding inheritance digunakan pada saat kita ingin mengambil properti dari class induk tapi tidak semuanya, atau hanya sebagian saja. atau dalam ilmu biologi, tidak mungkin anak sama persis dengan induknya.
# ![](./img/overriding-in-java.png)
#
# contoh overriding![](./img/000.png)
#
# outputnya > ![](./img/001.png)
#
#
#
# c. Super
#
#     Fungsi ini biasa digunakan ketika ingin menambahkan keunikan kelas anak dari induknya paling umum fungsi ini menggunakan metode super().__init__()
#
#  ![](./img/01%20super.png)
#  outputnya > ![](./img/02%20super.png)

# %% [markdown]
#  Polymorphisme
#
#      Operasi yang sama mungkin mempunyai perbedaan dalam kelas yang berbeda,atau suatu objek datang dalam banyak jenis atau bentuk.tetapi logika nya mereka  sama. dalam bahasa polimorfisme sendiri diartikan poli artinya banyak dan morphs artinya bentuk . artinya polimorfisme adalah banyak bentuk.
#
#
#  ![](./img/01%20poli.png)
#     dari gambar diatas dua objek yang menggunakan antarmuka umum, kita dapat menggunakan dua objek dengan cara yang sama terlepas dari jenisnya masing-masing.
#
# - Polimorfisme menggunakan Fungsi
#   Kita membuat dua kelas: Bear dan Dog, keduanya dapat membuat suara yang berbeda. Kemudian kita membuat dua contoh dan memanggil mereka menggunakan metode yang sama.![00.png](attachment:00.png)
#
# - Polimorfisme Menggunakan Method
#     dua objek, sammy dari kelas Shark, dan casey dari kelas Clownfish.
# kita mengulanginya menggunakan perulangan For pada objek-objek ini, memanggil swim (), swim_backwards (),
# dan metode skeleton () pada masing-masing kelas.
# ![](./img/03%20pooli.png)
# Kemudian outputnya akan seperti ini > ![](./img/04%20pooli.png)
#
# - Abstract Class
#     kelas abstrak dokumen. Kelas ini tidak memiliki implementasi tetapi mendefinisikan struktur (dalam bentuk fungsi) yang harus dimiliki semua bentuk.
# Jika kita mendefinisikan fungsi show () maka baik PdfDocument dan WordDocument harus memiliki fungsi show ()
# ![](./img/05%20poli.png)
# yang menunjukkan abstract class adalah > ![](./img/06%20poli.png)
# Kemudian outputnya adalah > ![](./img/07%20poli.png)

# %% [markdown]
# Operator Overloading
#
# - Overloading
#     ![](./img/1%20ovl.png)
# -  Definisi
#
#
#     Diberikan metode atau fungsi tunggal, kita dapat menentukan jumlah parameter sendiri. Bergantung pada definisi fungsi, dapat dipanggil dengan parameter nol, satu, dua atau lebih.
#
# - Method Overloading
#
#      Contoh Method Overloading
#   Memanggil method menggunakan parameter
# ![](./img/01%20%282%29.jpg)
# - Operator Overloading
#         Biasanya operator hanya bisa mendefinisikan satu str dan int, pada operator overloading anda bisa atau mungkin bisa mendefinisikan dua str dan dua int atau lebih
#   ![](./img/images.png)
#     operator overloading biasanya juga bisa menggunakan Magic Method seperti
#     x + y menggunakan Magic Method x__add__(y):
#
#  coding :
# ![](./img/02%20%282%29.jpg)

# %% [markdown]
#                                     ENCAPSULATION
#     Digunakan untuk memasukkan keyword yang bersifat pribadi atau private . biasanya mengaksesnya bisa menggunakan gaaris bawah. dan dapat diakses diluar kelas
# ![](./img/13.png)
#
# Mengakses private variabel
# ![](./img/as.jpg)
# gambar code diatas merupakan mengakses private dengan salah atau error pada pemanggilan private variabel
# ![](./img/as2.jpg)
#
# Yang benar adalah dengan menambahkan nama kelas setelah obj.
# Satu garis bawah: Variabel pribadi, tidak boleh diakses secara langsung. Tetapi tidak ada yang menghentikan Anda dari melakukan itu (kecuali konvensi).
# Garis bawah ganda: Variabel pribadi, lebih sulit diakses tetapi masih memungkinkan dengan memanggil nama class nya
#
#
# - Private Method
#
#     Fungsi yang tidak dapat dipanggil pada objek secara langsung, hanya dari dalam kelas
#     ![](./img/05.jpg)
#
#     __updateSoftware adalah private method dalam class tersebut
#
# - Private Variabel
#     Variabel pribadi hanya dapat diubah dalam metode kelas dan tidak di luar kelas.
#
# ![./img/](./img/06.jpg)
#
# Private dapat diubah dengan cara :
# ![](./img/07.jpg)
